# %% [markdown]
# # Clean & Analyze Social Media

# %% [markdown]
# ## Introduction
#
# Social media has become a ubiquitous part of modern life, with platforms such as Instagram, Twitter, and Facebook serving as essential communication channels. Social media data sets are vast and complex, making analysis a challenging task for businesses and researchers alike. In this project, we explore a simulated social media, for example Tweets, data set to understand trends in likes across different categories.
#
# ## Prerequisites
#
# To follow along with this project, you should have a basic understanding of Python programming and data analysis concepts. In addition, you may want to use the following packages in your Python environment:
#
# - pandas
# - Matplotlib
# - ...
#
# These packages should already be installed in Coursera's Jupyter Notebook environment, however if you'd like to install additional packages that are not included in this environment or are working off platform you can install additional packages using `!pip install packagename` within a notebook cell such as:
#
# - `!pip install pandas`
# - `!pip install matplotlib`
#
# ## Project Scope
#
# The objective of this project is to analyze tweets (or other social media data) and gain insights into user engagement. We will explore the data set using visualization techniques to understand the distribution of likes across different categories. Finally, we will analyze the data to draw conclusions about the most popular categories and the overall engagement on the platform.
#
# ## Step 1: Importing Required Libraries
#
# As the name suggests, the first step is to import all the necessary libraries that will be used in the project. In this case, we need pandas, numpy, matplotlib, seaborn, and random libraries.
#
# Pandas is a library used for data manipulation and analysis. Numpy is a library used for numerical computations. Matplotlib is a library used for data visualization. Seaborn is a library used for statistical data visualization. Random is a library used to generate random numbers.

# %%
import pandas as pd

# Expanded dataset with more null and duplicate data
data = {
    "Timestamp": [
        "2024-11-30 08:00:00", "2024-12-31 09:30:00", "2024-12-29 10:00:00", "2024-12-28 11:00:00", "2024-12-30 12:15:00", 
        "2024-12-26 13:00:00", "2024-12-20 14:45:00", "2024-12-24 16:00:00", "2024-12-25 17:30:00", "2024-12-30 18:00:00", 
        "2024-12-27 19:00:00", "2024-12-20 20:30:00", "2024-12-22 21:00:00", pd.NaT, "2024-12-26 12:00:00", 
        "2024-12-31 08:00:00", pd.NaT, "2024-12-30 22:00:00", "2024-12-30 23:15:00", pd.NaT, "2024-12-30 23:45:00", "2024-12-30 23:59:00"
    ],
    "Username": [
        "@fit_joe", "@techguru", "@healthnut", "@beautychic", "@techqueen", 
        "@familyguy", "@fit_mom", "@techguru", "@beautychic", "@healthnut", 
        "@familyguy", "@techqueen", "@fit_joe", "@techie", "@techqueen", 
        "@fit_joe", "@healthnut", "@fit_mom", "@beautychic", "@techguru", 
        "@familyguy", "@techqueen"
    ],
    "Tweet": [
        "Starting the day with a morning workout. Let's crush this #fitness goal! 💪 #motivation", 
        "New iPhone 15 is out! Who's getting it? 🤔 #Apple #Tech", 
        "Just tried a new healthy smoothie recipe! Highly recommend! #health #food", 
        "Loving my new skincare routine! Glowing skin all day! #Beauty #Skincare", 
        "Tech lovers, the new Android update is a game-changer. #android #tech", 
        "Family dinner night was a success! So much fun! #family #dinner", 
        "Loving my new workout routine. I'm feeling stronger every day! 💪 #fitness #workout", 
        "The latest in AI technology is blowing my mind. #AI #Tech", 
        "Can't stop using my new lip gloss! Best purchase ever. 💄 #beauty #makeup", 
        "Try this protein shake recipe after your workout. It helps recover fast. #health #fitness", 
        "Spent quality time with the kids today. Cherish these moments. #family #love", 
        "Is anyone else excited about the new Windows update? #Windows #Tech", 
        "Fueling up for tomorrow's workout with some great meals today! 🥗🍗 #fitness #mealprep", 
        "Exploring the wonders of VR technology. The future is here! #VR #Tech", 
        "The new Windows update is full of surprises! #Windows #Tech", 
        "Starting the day with a morning workout. Let's crush this #fitness goal! 💪 #motivation", 
        "Can't wait to start my new diet plan next week! #diet #health", 
        "Quick workout before dinner! #fitness #quickworkout", 
        "Love my new beauty blender! #makeup #beauty", 
        "Tech enthusiasts, do you follow the latest VR news? #VR #Tech", 
        "Just had an amazing family day! #family #love", 
        "VR is going to change everything. Can't wait for the future. #VR #Tech"
    ],
    "Likes": [
        120, 300, 250, 180, 90, 150, 500, 450, 220, 190, 300, 80, 150, 250, 100, 
        120, 0, 350, 180, 250, 400, 200
    ],
    "Retweets": [
        30, 100, 50, 40, 10, 20, 200, 90, 60, 50, 80, 20, 30, 50, 30, 
        30, 0, 70, 30, 60, 120, 40
    ],
    "Cleaned_Tweet": [
        "starting the day with a morning workout lets crush this fitness goal motivation", 
        "new iphone 15 is out whos getting it apple tech", 
        "just tried a new healthy smoothie recipe highly recommend health food", 
        "loving my new skincare routine glowing skin all day beauty skincare", 
        "tech lovers the new android update is a gamechanger android tech", 
        "family dinner night was a success so much fun family dinner", 
        "loving my new workout routine im feeling stronger every day fitness workout", 
        "the latest in ai technology is blowing my mind ai tech", 
        "cant stop using my new lip gloss best purchase ever beauty makeup", 
        "try this protein shake recipe after your workout it helps recover fast health fitness", 
        "spent quality time with the kids today cherish these moments family love", 
        "is anyone else excited about the new windows update windows tech", 
        "fueling up for tomorrows workout with some great meals today fitness mealprep", 
        "exploring the wonders of vr technology the future is here vr tech", 
        "the new windows update is full of surprises windows tech", 
        "starting the day with a morning workout lets crush this fitness goal motivation", 
        "cant wait to start my new diet plan next week diet health", 
        "quick workout before dinner fitness quickworkout", 
        "love my new beauty blender makeup beauty", 
        "tech enthusiasts do you follow the latest vr news vr tech", 
        "just had an amazing family day family love", 
        "vr is going to change everything cant wait for the future vr tech"
    ],
    "Sentiment": [
        0.35, 0.2, 0.45, 0.5, 0.15, 0.6, 0.6, 0.3, 0.7, 0.4, 0.8, 0.1, 0.5, 0.45, 0.3, 
        0.35, None, 0.4, 0.6, 0.45, 0.8, 0.45
    ]
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Convert 'Timestamp' to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# %%
df.head()
# Out:
#             Timestamp     Username  \
# 0 2024-11-30 08:00:00     @fit_joe
# 1 2024-12-31 09:30:00    @techguru
# 2 2024-12-29 10:00:00   @healthnut
# 3 2024-12-28 11:00:00  @beautychic
# 4 2024-12-30 12:15:00   @techqueen
#
#                                                Tweet  Likes  Retweets  \
# 0  Starting the day with a morning workout. Let's...    120        30
# 1  New iPhone 15 is out! Who's getting it? 🤔 #App...    300       100
# 2  Just tried a new healthy smoothie recipe! High...    250        50
# 3  Loving my new skincare routine! Glowing skin a...    180        40
# 4  Tech lovers, the new Android update is a game-...     90        10
#
#                                        Cleaned_Tweet  Sentiment
# 0  starting the day with a morning workout lets c...       0.35
# 1    new iphone 15 is out whos getting it apple tech       0.20
# 2  just tried a new healthy smoothie recipe highl...       0.45
# 3  loving my new skincare routine glowing skin al...       0.50
# ...

# %%
df.tail()
# Out:
#              Timestamp     Username  \
# 17 2024-12-30 22:00:00     @fit_mom
# 18 2024-12-30 23:15:00  @beautychic
# 19                 NaT    @techguru
# 20 2024-12-30 23:45:00   @familyguy
# 21 2024-12-30 23:59:00   @techqueen
#
#                                                 Tweet  Likes  Retweets  \
# 17  Quick workout before dinner! #fitness #quickwo...    350        70
# 18        Love my new beauty blender! #makeup #beauty    180        30
# 19  Tech enthusiasts, do you follow the latest VR ...    250        60
# 20      Just had an amazing family day! #family #love    400       120
# 21  VR is going to change everything. Can't wait f...    200        40
#
#                                         Cleaned_Tweet  Sentiment
# 17   quick workout before dinner fitness quickworkout       0.40
# 18           love my new beauty blender makeup beauty       0.60
# 19  tech enthusiasts do you follow the latest vr n...       0.45
# ...

# %% [markdown]
# Shape of the dataframe

# %%
df.shape
# Out:
# (22, 7)

# %% [markdown]
# Df information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22 entries, 0 to 21
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      19 non-null     datetime64[ns]
#  1   Username       22 non-null     object
#  2   Tweet          22 non-null     object
#  3   Likes          22 non-null     int64
#  4   Retweets       22 non-null     int64
#  5   Cleaned_Tweet  22 non-null     object
#  6   Sentiment      21 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 1.3+ KB

# %%
df.describe()
# Out:
#             Likes    Retweets  Sentiment
# count   22.000000   22.000000  21.000000
# mean   219.545455   55.000000   0.450000
# std    125.298777   43.942603   0.190394
# min      0.000000    0.000000   0.100000
# 25%    127.500000   30.000000   0.350000
# 50%    195.000000   45.000000   0.450000
# 75%    287.500000   67.500000   0.600000
# max    500.000000  200.000000   0.800000

# %% [markdown]
# To include non numerical field as well

# %%
df.describe(include = 'all')
# Out:
#                   Timestamp    Username  \
# count                    19          22
# unique                   19           8
# top     2024-12-29 10:00:00  @techqueen
# freq                      1           4
# first   2024-11-30 08:00:00         NaN
# last    2024-12-31 09:30:00         NaN
# mean                    NaN         NaN
# std                     NaN         NaN
# min                     NaN         NaN
# 25%                     NaN         NaN
# 50%                     NaN         NaN
# 75%                     NaN         NaN
# max                     NaN         NaN
#
#                                                     Tweet       Likes  \
# count                                                  22   22.000000
# unique                                                 21         NaN
# top     Starting the day with a morning workout. Let's...         NaN
# freq                                                    2         NaN
# ...

# %%
df.count()
# Out:
# Timestamp        19
# Username         22
# Tweet            22
# Likes            22
# Retweets         22
# Cleaned_Tweet    22
# Sentiment        21
# dtype: int64

# %% [markdown]
# Checking for Missing Data

# %%
df.isnull().sum()
# Out:
# Timestamp        3
# Username         0
# Tweet            0
# Likes            0
# Retweets         0
# Cleaned_Tweet    0
# Sentiment        1
# dtype: int64

# %% [markdown]
# To drop the row with missing data

# %%
dropped_df=df.dropna()

# %%
dropped_df
# Out:
#              Timestamp     Username  \
# 0  2024-11-30 08:00:00     @fit_joe
# 1  2024-12-31 09:30:00    @techguru
# 2  2024-12-29 10:00:00   @healthnut
# 3  2024-12-28 11:00:00  @beautychic
# 4  2024-12-30 12:15:00   @techqueen
# 5  2024-12-26 13:00:00   @familyguy
# 6  2024-12-20 14:45:00     @fit_mom
# 7  2024-12-24 16:00:00    @techguru
# 8  2024-12-25 17:30:00  @beautychic
# 9  2024-12-30 18:00:00   @healthnut
# 10 2024-12-27 19:00:00   @familyguy
# 11 2024-12-20 20:30:00   @techqueen
# 12 2024-12-22 21:00:00     @fit_joe
# 14 2024-12-26 12:00:00   @techqueen
# 15 2024-12-31 08:00:00     @fit_joe
# 17 2024-12-30 22:00:00     @fit_mom
# 18 2024-12-30 23:15:00  @beautychic
# 20 2024-12-30 23:45:00   @familyguy
# 21 2024-12-30 23:59:00   @techqueen
#
#                                                 Tweet  Likes  Retweets  \
# 0   Starting the day with a morning workout. Let's...    120        30
# 1   New iPhone 15 is out! Who's getting it? 🤔 #App...    300       100
# ...

# %% [markdown]
# Row 13,16,19 (index 13,16,19) is missing

# %% [markdown]
# Resetting the index

# %%
dropped_df.reset_index()
# Out:
#     index           Timestamp     Username  \
# 0       0 2024-11-30 08:00:00     @fit_joe
# 1       1 2024-12-31 09:30:00    @techguru
# 2       2 2024-12-29 10:00:00   @healthnut
# 3       3 2024-12-28 11:00:00  @beautychic
# 4       4 2024-12-30 12:15:00   @techqueen
# 5       5 2024-12-26 13:00:00   @familyguy
# 6       6 2024-12-20 14:45:00     @fit_mom
# 7       7 2024-12-24 16:00:00    @techguru
# 8       8 2024-12-25 17:30:00  @beautychic
# 9       9 2024-12-30 18:00:00   @healthnut
# 10     10 2024-12-27 19:00:00   @familyguy
# 11     11 2024-12-20 20:30:00   @techqueen
# 12     12 2024-12-22 21:00:00     @fit_joe
# 13     14 2024-12-26 12:00:00   @techqueen
# 14     15 2024-12-31 08:00:00     @fit_joe
# 15     17 2024-12-30 22:00:00     @fit_mom
# 16     18 2024-12-30 23:15:00  @beautychic
# 17     20 2024-12-30 23:45:00   @familyguy
# 18     21 2024-12-30 23:59:00   @techqueen
#
#                                                 Tweet  Likes  Retweets  \
# ...

# %% [markdown]
# Drop the previous index

# %%
dropped_df.reset_index(drop = True, inplace = True)

# %%
dropped_df
# Out:
#              Timestamp     Username  \
# 0  2024-11-30 08:00:00     @fit_joe
# 1  2024-12-31 09:30:00    @techguru
# 2  2024-12-29 10:00:00   @healthnut
# 3  2024-12-28 11:00:00  @beautychic
# 4  2024-12-30 12:15:00   @techqueen
# 5  2024-12-26 13:00:00   @familyguy
# 6  2024-12-20 14:45:00     @fit_mom
# 7  2024-12-24 16:00:00    @techguru
# 8  2024-12-25 17:30:00  @beautychic
# 9  2024-12-30 18:00:00   @healthnut
# 10 2024-12-27 19:00:00   @familyguy
# 11 2024-12-20 20:30:00   @techqueen
# 12 2024-12-22 21:00:00     @fit_joe
# 13 2024-12-26 12:00:00   @techqueen
# 14 2024-12-31 08:00:00     @fit_joe
# 15 2024-12-30 22:00:00     @fit_mom
# 16 2024-12-30 23:15:00  @beautychic
# 17 2024-12-30 23:45:00   @familyguy
# 18 2024-12-30 23:59:00   @techqueen
#
#                                                 Tweet  Likes  Retweets  \
# 0   Starting the day with a morning workout. Let's...    120        30
# 1   New iPhone 15 is out! Who's getting it? 🤔 #App...    300       100
# ...

# %% [markdown]
# Convert column into index

# %%
dropped_df.set_index('Timestamp')
# Out:
#                         Username  \
# Timestamp
# 2024-11-30 08:00:00     @fit_joe
# 2024-12-31 09:30:00    @techguru
# 2024-12-29 10:00:00   @healthnut
# 2024-12-28 11:00:00  @beautychic
# 2024-12-30 12:15:00   @techqueen
# 2024-12-26 13:00:00   @familyguy
# 2024-12-20 14:45:00     @fit_mom
# 2024-12-24 16:00:00    @techguru
# 2024-12-25 17:30:00  @beautychic
# 2024-12-30 18:00:00   @healthnut
# 2024-12-27 19:00:00   @familyguy
# 2024-12-20 20:30:00   @techqueen
# 2024-12-22 21:00:00     @fit_joe
# 2024-12-26 12:00:00   @techqueen
# 2024-12-31 08:00:00     @fit_joe
# 2024-12-30 22:00:00     @fit_mom
# 2024-12-30 23:15:00  @beautychic
# 2024-12-30 23:45:00   @familyguy
# 2024-12-30 23:59:00   @techqueen
#
#                                                                  Tweet  Likes  \
# Timestamp
# 2024-11-30 08:00:00  Starting the day with a morning workout. Let's...    120
# 2024-12-31 09:30:00  New iPhone 15 is out! Who's getting it? 🤔 #App...    300
# ...

# %%
df.tail()
# Out:
#              Timestamp     Username  \
# 17 2024-12-30 22:00:00     @fit_mom
# 18 2024-12-30 23:15:00  @beautychic
# 19                 NaT    @techguru
# 20 2024-12-30 23:45:00   @familyguy
# 21 2024-12-30 23:59:00   @techqueen
#
#                                                 Tweet  Likes  Retweets  \
# 17  Quick workout before dinner! #fitness #quickwo...    350        70
# 18        Love my new beauty blender! #makeup #beauty    180        30
# 19  Tech enthusiasts, do you follow the latest VR ...    250        60
# 20      Just had an amazing family day! #family #love    400       120
# 21  VR is going to change everything. Can't wait f...    200        40
#
#                                         Cleaned_Tweet  Sentiment
# 17   quick workout before dinner fitness quickworkout       0.40
# 18           love my new beauty blender makeup beauty       0.60
# 19  tech enthusiasts do you follow the latest vr n...       0.45
# ...

# %% [markdown]
# Fill the timestamp with previous timestamp and sentiment with its mean value if null

# %%
df['Timestamp'] = df['Timestamp'].fillna(method='ffill')  # Forward fill for 'Timestamp'
df['Sentiment'] = df['Sentiment'].fillna(df['Sentiment'].mean())  # Fill 'Sentiment' NaNs with the mean of 'Sentiment'

# %%
df.isnull().sum()
# Out:
# Timestamp        0
# Username         0
# Tweet            0
# Likes            0
# Retweets         0
# Cleaned_Tweet    0
# Sentiment        0
# dtype: int64

# %% [markdown]
# Handling duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# drop all the duplicates

# %%
df.drop_duplicates(keep=False).reset_index()
# Out:
#     index           Timestamp     Username  \
# 0       0 2024-11-30 08:00:00     @fit_joe
# 1       1 2024-12-31 09:30:00    @techguru
# 2       2 2024-12-29 10:00:00   @healthnut
# 3       3 2024-12-28 11:00:00  @beautychic
# 4       4 2024-12-30 12:15:00   @techqueen
# 5       5 2024-12-26 13:00:00   @familyguy
# 6       6 2024-12-20 14:45:00     @fit_mom
# 7       7 2024-12-24 16:00:00    @techguru
# 8       8 2024-12-25 17:30:00  @beautychic
# 9       9 2024-12-30 18:00:00   @healthnut
# 10     10 2024-12-27 19:00:00   @familyguy
# 11     11 2024-12-20 20:30:00   @techqueen
# 12     12 2024-12-22 21:00:00     @fit_joe
# 13     13 2024-12-22 21:00:00      @techie
# 14     14 2024-12-26 12:00:00   @techqueen
# 15     15 2024-12-31 08:00:00     @fit_joe
# 16     16 2024-12-31 08:00:00   @healthnut
# 17     17 2024-12-30 22:00:00     @fit_mom
# 18     18 2024-12-30 23:15:00  @beautychic
# 19     19 2024-12-30 23:15:00    @techguru
# 20     20 2024-12-30 23:45:00   @familyguy
# ...

# %% [markdown]
# Drop all the duplicates but keep the first occurence. Default

# %%
df.drop_duplicates(keep='first').reset_index()
# Out:
#     index           Timestamp     Username  \
# 0       0 2024-11-30 08:00:00     @fit_joe
# 1       1 2024-12-31 09:30:00    @techguru
# 2       2 2024-12-29 10:00:00   @healthnut
# 3       3 2024-12-28 11:00:00  @beautychic
# 4       4 2024-12-30 12:15:00   @techqueen
# 5       5 2024-12-26 13:00:00   @familyguy
# 6       6 2024-12-20 14:45:00     @fit_mom
# 7       7 2024-12-24 16:00:00    @techguru
# 8       8 2024-12-25 17:30:00  @beautychic
# 9       9 2024-12-30 18:00:00   @healthnut
# 10     10 2024-12-27 19:00:00   @familyguy
# 11     11 2024-12-20 20:30:00   @techqueen
# 12     12 2024-12-22 21:00:00     @fit_joe
# 13     13 2024-12-22 21:00:00      @techie
# 14     14 2024-12-26 12:00:00   @techqueen
# 15     15 2024-12-31 08:00:00     @fit_joe
# 16     16 2024-12-31 08:00:00   @healthnut
# 17     17 2024-12-30 22:00:00     @fit_mom
# 18     18 2024-12-30 23:15:00  @beautychic
# 19     19 2024-12-30 23:15:00    @techguru
# 20     20 2024-12-30 23:45:00   @familyguy
# ...

# %% [markdown]
# Drop all the duplicates but keep the last occurence

# %%
df.drop_duplicates(keep='last')
# Out:
#              Timestamp     Username  \
# 0  2024-11-30 08:00:00     @fit_joe
# 1  2024-12-31 09:30:00    @techguru
# 2  2024-12-29 10:00:00   @healthnut
# 3  2024-12-28 11:00:00  @beautychic
# 4  2024-12-30 12:15:00   @techqueen
# 5  2024-12-26 13:00:00   @familyguy
# 6  2024-12-20 14:45:00     @fit_mom
# 7  2024-12-24 16:00:00    @techguru
# 8  2024-12-25 17:30:00  @beautychic
# 9  2024-12-30 18:00:00   @healthnut
# 10 2024-12-27 19:00:00   @familyguy
# 11 2024-12-20 20:30:00   @techqueen
# 12 2024-12-22 21:00:00     @fit_joe
# 13 2024-12-22 21:00:00      @techie
# 14 2024-12-26 12:00:00   @techqueen
# 15 2024-12-31 08:00:00     @fit_joe
# 16 2024-12-31 08:00:00   @healthnut
# 17 2024-12-30 22:00:00     @fit_mom
# 18 2024-12-30 23:15:00  @beautychic
# 19 2024-12-30 23:15:00    @techguru
# 20 2024-12-30 23:45:00   @familyguy
# 21 2024-12-30 23:59:00   @techqueen
#
#                                                 Tweet  Likes  Retweets  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.reset_index(drop=True)
# Out:
#              Timestamp     Username  \
# 0  2024-11-30 08:00:00     @fit_joe
# 1  2024-12-31 09:30:00    @techguru
# 2  2024-12-29 10:00:00   @healthnut
# 3  2024-12-28 11:00:00  @beautychic
# 4  2024-12-30 12:15:00   @techqueen
# 5  2024-12-26 13:00:00   @familyguy
# 6  2024-12-20 14:45:00     @fit_mom
# 7  2024-12-24 16:00:00    @techguru
# 8  2024-12-25 17:30:00  @beautychic
# 9  2024-12-30 18:00:00   @healthnut
# 10 2024-12-27 19:00:00   @familyguy
# 11 2024-12-20 20:30:00   @techqueen
# 12 2024-12-22 21:00:00     @fit_joe
# 13 2024-12-22 21:00:00      @techie
# 14 2024-12-26 12:00:00   @techqueen
# 15 2024-12-31 08:00:00     @fit_joe
# 16 2024-12-31 08:00:00   @healthnut
# 17 2024-12-30 22:00:00     @fit_mom
# 18 2024-12-30 23:15:00  @beautychic
# 19 2024-12-30 23:15:00    @techguru
# 20 2024-12-30 23:45:00   @familyguy
# 21 2024-12-30 23:59:00   @techqueen
#
#                                                 Tweet  Likes  Retweets  \
# ...

# %% [markdown]
# Data Transformation

# %% [markdown]
# Convert the Timestamp column to a datetime object if it is not already in that format.

# %%
# Convert Timestamp to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'])

# Check data types
print(df.dtypes)
# Out:
# Timestamp        datetime64[ns]
# Username                 object
# Tweet                    object
# Likes                     int64
# Retweets                  int64
# Cleaned_Tweet            object
# Sentiment               float64
# dtype: object

# %% [markdown]
# Extract the hour and day of the week from the Timestamp column and create new columns for these.

# %%
df['Hour']=df['Timestamp'].dt.hour
df['Week']=df['Timestamp'].dt.week
df['Day_of_Week'] = df['Timestamp'].dt.day_name()

# %%
df.head()
# Out:
#             Timestamp     Username  \
# 0 2024-11-30 08:00:00     @fit_joe
# 1 2024-12-31 09:30:00    @techguru
# 2 2024-12-29 10:00:00   @healthnut
# 3 2024-12-28 11:00:00  @beautychic
# 4 2024-12-30 12:15:00   @techqueen
#
#                                                Tweet  Likes  Retweets  \
# 0  Starting the day with a morning workout. Let's...    120        30
# 1  New iPhone 15 is out! Who's getting it? 🤔 #App...    300       100
# 2  Just tried a new healthy smoothie recipe! High...    250        50
# 3  Loving my new skincare routine! Glowing skin a...    180        40
# 4  Tech lovers, the new Android update is a game-...     90        10
#
#                                        Cleaned_Tweet  Sentiment  Hour  Week  \
# 0  starting the day with a morning workout lets c...       0.35     8    48
# 1    new iphone 15 is out whos getting it apple tech       0.20     9     1
# 2  just tried a new healthy smoothie recipe highl...       0.45    10    52
# ...

# %% [markdown]
# Drop column

# %%
df.drop(['Week'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['Timestamp', 'Username', 'Tweet', 'Likes', 'Retweets', 'Cleaned_Tweet',
#        'Sentiment', 'Hour', 'Day_of_Week'],
#       dtype='object')

# %% [markdown]
# Descriptive statistics

# %%
# Descriptive statistics for numerical columns
df[['Likes', 'Retweets', 'Sentiment']].describe()
# Out:
#             Likes    Retweets  Sentiment
# count   22.000000   22.000000  22.000000
# mean   219.545455   55.000000   0.450000
# std    125.298777   43.942603   0.185806
# min      0.000000    0.000000   0.100000
# 25%    127.500000   30.000000   0.350000
# 50%    195.000000   45.000000   0.450000
# 75%    287.500000   67.500000   0.575000
# max    500.000000  200.000000   0.800000

# %% [markdown]
# Data Aggregation and Grouping

# %%
df.head()
# Out:
#             Timestamp     Username  \
# 0 2024-11-30 08:00:00     @fit_joe
# 1 2024-12-31 09:30:00    @techguru
# 2 2024-12-29 10:00:00   @healthnut
# 3 2024-12-28 11:00:00  @beautychic
# 4 2024-12-30 12:15:00   @techqueen
#
#                                                Tweet  Likes  Retweets  \
# 0  Starting the day with a morning workout. Let's...    120        30
# 1  New iPhone 15 is out! Who's getting it? 🤔 #App...    300       100
# 2  Just tried a new healthy smoothie recipe! High...    250        50
# 3  Loving my new skincare routine! Glowing skin a...    180        40
# 4  Tech lovers, the new Android update is a game-...     90        10
#
#                                        Cleaned_Tweet  Sentiment  Hour  \
# 0  starting the day with a morning workout lets c...       0.35     8
# 1    new iphone 15 is out whos getting it apple tech       0.20     9
# 2  just tried a new healthy smoothie recipe highl...       0.45    10
# ...

# %%
df.groupby(by='Username').count()['Tweet']
# Out:
# Username
# @beautychic    3
# @familyguy     3
# @fit_joe       3
# @fit_mom       2
# @healthnut     3
# @techguru      3
# @techie        1
# @techqueen     4
# Name: Tweet, dtype: int64

# %%
df.groupby(by=['Username','Timestamp']).count()['Tweet']
# Out:
# Username     Timestamp
# @beautychic  2024-12-25 17:30:00    1
#              2024-12-28 11:00:00    1
#              2024-12-30 23:15:00    1
# @familyguy   2024-12-26 13:00:00    1
#              2024-12-27 19:00:00    1
#              2024-12-30 23:45:00    1
# @fit_joe     2024-11-30 08:00:00    1
#              2024-12-22 21:00:00    1
#              2024-12-31 08:00:00    1
# @fit_mom     2024-12-20 14:45:00    1
#              2024-12-30 22:00:00    1
# @healthnut   2024-12-29 10:00:00    1
#              2024-12-30 18:00:00    1
#              2024-12-31 08:00:00    1
# @techguru    2024-12-24 16:00:00    1
#              2024-12-30 23:15:00    1
#              2024-12-31 09:30:00    1
# @techie      2024-12-22 21:00:00    1
# @techqueen   2024-12-20 20:30:00    1
#              2024-12-26 12:00:00    1
#              2024-12-30 12:15:00    1
#              2024-12-30 23:59:00    1
# Name: Tweet, dtype: int64

# %%
df.groupby('Username').agg(
    Tweet=('Tweet', 'count'),   # Count the number of tweets per user
    Likes=('Likes', 'sum')      # Sum the number of likes per user
)
# Out:
#              Tweet  Likes
# Username
# @beautychic      3    580
# @familyguy       3    850
# @fit_joe         3    390
# @fit_mom         2    850
# @healthnut       3    440
# @techguru        3   1000
# @techie          1    250
# @techqueen       4    470

# %%
# Group by Username and calculate mean statistics
user_stats = df.groupby('Username')[['Sentiment', 'Likes', 'Retweets']].mean()

# Display top users by Sentiment and Likes
print(user_stats.sort_values(by='Sentiment', ascending=False).head(1))
print(user_stats.sort_values(by='Likes', ascending=False).head(1))
# Out:
#             Sentiment       Likes   Retweets
# Username
# @familyguy   0.733333  283.333333  73.333333
#           Sentiment  Likes  Retweets
# Username
# @fit_mom        0.5  425.0     135.0

# %% [markdown]
# Data Visualization

# %% [markdown]
# Task: Plot a histogram of the Sentiment column to visualize its distribution.
# Question: Does the Sentiment data appear to be normally distributed, or does it lean toward positive/negative sentiments?

# %%
import matplotlib.pyplot as plt

# Histogram of Sentiment
plt.figure(figsize=(8, 6))
plt.hist(df['Sentiment'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Sentiment')
plt.xlabel('Sentiment')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Task: Plot a scatter plot of Likes vs. Retweets to see if there is any correlation between the two.
# Question: Is there a correlation between the number of Likes and Retweets?

# %%
# Scatter plot of Likes vs Retweets
plt.figure(figsize=(8, 6))
plt.scatter(df['Likes'], df['Retweets'], alpha=0.5, color='purple')
plt.title('Likes vs Retweets')
plt.xlabel('Likes')
plt.ylabel('Retweets')
plt.show()

# %% [markdown]
# Task: Create a bar plot to visualize the average Sentiment by Day of Week.
# Question: Which day of the week has the highest average Sentiment?

# %%
# Average Sentiment by Day of Week
avg_sentiment_by_day = df.groupby('Day_of_Week')['Sentiment'].mean()

# Bar plot of average Sentiment by Day of Week
avg_sentiment_by_day = avg_sentiment_by_day.reindex(['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
plt.figure(figsize=(10, 6))
avg_sentiment_by_day.plot(kind='bar', color='lightcoral')
plt.title('Average Sentiment by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Average Sentiment')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Correlation Analysis

# %% [markdown]
# Task: Compute the correlation matrix for numerical columns such as Likes, Retweets, and Sentiment.
# Question: Is there a strong correlation between any of the numerical columns (e.g., Likes and Retweets)?

# %%
# Correlation matrix
correlation_matrix = df[['Likes', 'Retweets', 'Sentiment']].corr()

# Display the correlation matrix
print(correlation_matrix)
# Out:
#               Likes  Retweets  Sentiment
# Likes      1.000000  0.906810   0.363055
# Retweets   0.906810  1.000000   0.355767
# Sentiment  0.363055  0.355767   1.000000

# %% [markdown]
# Advanced Filtering & Analysis

# %% [markdown]
# Task: Filter the dataset to only include tweets related to "fitness" (i.e., rows where the Tweet contains the word "fitness").
# Question: What is the average Sentiment and Likes for tweets related to fitness?

# %%
# Filter tweets related to fitness
fitness_tweets = df[df['Tweet'].str.contains('fitness', case=False)]

# Calculate average Sentiment and Likes for fitness tweets
print(fitness_tweets[['Sentiment', 'Likes']].mean())
# Out:
# Sentiment      0.433333
# Likes        238.333333
# dtype: float64

# %% [markdown]
# Text Analysis

# %% [markdown]
# Task: Perform a word count analysis on the tweets to see which words are most frequently used.
# Question: What are the most common words used in the tweets? Can you identify any significant patterns in the vocabulary of specific categories (e.g., fitness, tech)?

# %%
from collections import Counter
import re

# Tokenize the tweets and clean the text
all_words = ' '.join(df['Tweet']).lower()
all_words = re.sub(r'[^\w\s]', '', all_words)

# Count the frequency of words
word_counts = Counter(all_words.split())

# Display the 10 most common words
print(word_counts.most_common(10))
# Out:
# [('the', 11), ('new', 10), ('tech', 10), ('workout', 7), ('is', 7), ('fitness', 6), ('my', 6), ('vr', 6), ('day', 5), ('a', 5)]

# %% [markdown]
# Time Series Analysis

# %% [markdown]
# Task: Group the data by hour and calculate the total number of Likes and Retweets for each hour of the day.
# Question: What time of day (hour) has the highest total engagement (Likes + Retweets)?

# %%
# Group by hour and calculate total Likes and Retweets
hourly_engagement = df.groupby('Hour')[['Likes', 'Retweets']].sum()

# Display hourly engagement
print(hourly_engagement)
# Out:
#       Likes  Retweets
# Hour
# 8       240        60
# 9       300       100
# 10      250        50
# 11      180        40
# 12      190        40
# 13      150        20
# 14      500       200
# 16      450        90
# 17      220        60
# 18      190        50
# 19      300        80
# 20       80        20
# 21      400        80
# 22      350        70
# 23     1030       250
